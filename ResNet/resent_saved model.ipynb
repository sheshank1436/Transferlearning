# %% [markdown]
# # using the saved model to get the predictions

# %% [markdown]
# #### import the required libraries

# %%
from keras.models import load_model
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# #### Calling the saved model

# %%
model=load_model('TSC_model.h5')

# %% [markdown]
# #### model summary

# %%
#model.summary()

# %% [markdown]
# #### model weights

# %%
#model.get_weights()

# %% [markdown]
# #### model optimizer

# %%
model.optimizer

# %% [markdown]
# ### prediction using the saved model

# %%
import cv2
img = cv2.imread('uparrow.jpg')
plt.imshow(img.astype('uint8'))
img = cv2.resize(img,(32,32))
img = np.reshape(img,[1,32,32,3])

classes = np.argmax(model.predict(img))
plt.title('Original: {} Predicted: {}'.format(('29'), np.argmax(model.predict(img))))
#print(classes)
# Out:
# Text(0.5, 1.0, 'Original: 29 Predicted: 29')
